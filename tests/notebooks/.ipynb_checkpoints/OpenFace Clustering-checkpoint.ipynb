# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import LabelEncoder

DIR = '../data/imdb/'

FEATURES_PATH = DIR + 'matrix.bin'
NAMES_PATH = DIR + 'names.txt'

# Load Files
FILE_LIMIT = 44500
FEATURES = np.fromfile(FEATURES_PATH, np.float32).reshape(-1, 128)[:FILE_LIMIT]
with open(NAMES_PATH, encoding='utf-8') as names_file:
    NAMES = names_file.read().split("\n")[:FILE_LIMIT]

label_encoder = LabelEncoder()
LABELS = label_encoder.fit_transform(NAMES)

# Bound By Number of Samples
MIN_SAMPLES = 40
MAX_SAMPLES = 45
unique, counts = np.unique(LABELS, return_counts=True)
COUNTS = counts[LABELS]
SELECTION = np.logical_and(COUNTS > MIN_SAMPLES, COUNTS < MAX_SAMPLES)

FEATURES = FEATURES[SELECTION]
LABELS = LABELS[SELECTION]
N_PERSONS = len(set(LABELS))

print(N_PERSONS, len(FEATURES) / N_PERSONS)
# Out:
# 11 42.90909090909091

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn import metrics


classifier = KNeighborsClassifier(20)

# Cross Validation Score
scores = cross_val_score(classifier, FEATURES, LABELS, cv=3)
print("Cross Validation Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))


FEATURES_TRAIN, FEATURES_TEST, LABELS_TRAIN, LABELS_TEST = train_test_split(FEATURES, LABELS, test_size=0.2)
classifier.fit(FEATURES_TRAIN, LABELS_TRAIN)

labels_predict = []

for distances, indices, truth in zip(*classifier.kneighbors(FEATURES_TEST), LABELS_TEST):
    labels = LABELS_TRAIN[indices]
    label = np.bincount(labels).argmax()
    
    score = np.mean(distances[labels == label]) / np.mean(distances[labels != label])
    
    print("{}\t{}\t".format(label, np.mean(distances[labels == label])), label == truth)
# Out:
# Cross Validation Accuracy: 0.69 (+/- 0.03)
# 49	0.7860480835013594	 True
# 338	0.825220684210121	 True
# 254	0.827034246083076	 True
# 278	0.4253910586903894	 True
# 313	0.7718919363957991	 True
# 126	0.8275728550483298	 True
# 313	0.7705465289496087	 True
# 126	0.8646829809521568	 True
# 49	0.5349197525201466	 True
# 124	0.7929113265695898	 True
# 201	0.927095054052092	 True
# 459	0.7928148267324829	 False
# 201	0.7028267659762041	 True
# 480	0.8965754162414526	 False
# 338	0.7832201191134582	 True
# 254	1.003163194804813	 False
# 124	0.7115939585929861	 True
# 201	0.9084053850765282	 True
# 254	0.6948870067618246	 True
# 459	0.7263465707313684	 True
# 459	0.6365614156466524	 True
# 124	1.051029090684775	 False
